# %% [markdown]
# #### For Beginners:
# **Printing patterns using python**
# - Please check the output to understand the **pattern** needed
# - Give it a try yourself
# - Then check the solution

# %%
def sq_pat(n=7):
    for i in range(n):
        print("*" * n)

def rect_pat(n=7):
    for i in range(n):
        print("*" * 11)
        
def right_trg_pat(n=7):
    spc = n-1
    for i in range(1,n+1):
        pat = "*" * i
        dsgn = pat + (" " * spc)
        print(dsgn)
        spc-=1

def inv_right_trg_pat(n=7):
    spc = 1
    for i in range(n,0,-1):
        pat = "*" * i
        dsgn = pat + (" " * spc)
        print(dsgn)
        spc+=1

def hollow_sq_pat(n=7):
    for i in range(1,n+1):
        if i in {1,n}:
            print("*" * n)
        else:
            pat = "*" + (" " * (n-2)) + "*"
            print(pat)
            
def hollow_rect_pat(n=7):
    for i in range(1,n+1):
        #if i in any([1,n]):
        if i in {1,n}:
            print("*" * 11)
        else:
            pat = "*" + (" " * (11-2)) + "*"
            print(pat)

def exp_incr_patr(n=5):
    prv = 2
    for i in range(1,n+1):
        if i == 1:
            print("*")
        elif i == 2:
            print("*" * 2) 
        else:
            print("*" * (prv * 2))
            prv = prv * 2  
            
def mir_tran_pat(n=7):
    spc = n-1
    for i in range(1,n+1):
        dsgn = (" " * spc)+("*" * i)
        print(dsgn)
        spc-=1           
        
def invrt_tran_pat(n=7):
    spc = 0
    for i in range(n,0,-1):
        dsgn = (" " * spc)+("*" * i) 
        print(dsgn)
        spc+=1       

def pyramid_pat(n=5):
    """
    - No. of rows(n) = 5
    - No. of element/row = (n*2) - 1 = 10 -1 =9
    Breakup: 
    - No. of stars/row = (i*2) - 1 
    - No. of spaces/row = int((ele_ech_row - star_cnt)/2)
    
    When:
    i=1
    ele_ech_row = 9
    star_cnt = (1*2)-1=1
    rem =(ele_ech_row - star_cnt)/2 = 4 spaces on either side
    
    When:
    i=2
    ele_ech_row = 9
    star_cnt = (2*2)-1=3
    rem =(ele_ech_row - star_cnt)/2 = (9-6)/3= 3 spaces on either side    

    """
    ele_ech_row = (n*2) - 1
    for i in range(1,n+1):
        star_cnt = (i*2)-1
        spc_cnt = int((ele_ech_row - star_cnt)/2)
        dsgn = (" "*spc_cnt) + ("*" * star_cnt) + (" "*spc_cnt)
        print(dsgn)

def inv_pyramid_pat(n=5):
    ele_ech_row = (n*2) - 1
    for i in range(n,0,-1):
        star_cnt = (i*2)-1
        spc_cnt = int((ele_ech_row - star_cnt)/2)
        dsgn = (" "*spc_cnt) + ("*" * star_cnt) + (" "*spc_cnt)
        print(dsgn)         
        
def rhombus_pat(n=5):
    spc = 0
    for i in range(n):
        dsgn = (" "*spc) + ("*" * n) 
        print(dsgn)
        spc+=1

# %%
print("1.Square pattern")
sq_pat()
print("\n2.Rectangle pattern")
rect_pat()
print("\n3.Right triangle pattern")
right_trg_pat()
print("\n4.Inverted Right triangle pattern")
inv_right_trg_pat()
print("\n5.Hollow square pattern")
hollow_sq_pat()
print("\n6.Hollow rect pattern")
hollow_rect_pat()
print("\n7.Exp increasing pattern")
exp_incr_patr()
print("\n8.Mirrored triangle pattern")
mir_tran_pat()
print("\n9.Inverted triangle pattern")
invrt_tran_pat()
print("\n10.Pyramid pattern")
pyramid_pat()
print("\n11.Inverted Pyramid pattern")
inv_pyramid_pat()
print("\n12.Rhombus pattern")
rhombus_pat()
# Out:
# 1.Square pattern
# *******
# *******
# *******
# *******
# *******
# *******
# *******
#
# 2.Rectangle pattern
# ***********
# ***********
# ***********
# ***********
# ***********
# ***********
# ***********
#
# 3.Right triangle pattern
# *
# **
# ***
# ****
# *****
# ******
# *******
#
# 4.Inverted Right triangle pattern
# *******
# ******
# *****
# ****
# ***
# **
# *
#
# 5.Hollow square pattern
# *******
# *     *
# *     *
# *     *
# *     *
# *     *
# *******
#
# 6.Hollow rect pattern
# ***********
# *         *
# *         *
# *         *
# *         *
# *         *
# ***********
#
# 7.Exp increasing pattern
# *
# **
# ****
# ********
# ****************
#
# 8.Mirrored triangle pattern
#       *
#      **
#     ***
#    ****
#   *****
#  ******
# *******
#
# 9.Inverted triangle pattern
# *******
#  ******
#   *****
#    ****
#     ***
#      **
#       *
#
# 10.Pyramid pattern
#     *
#    ***
#   *****
#  *******
# *********
#
# 11.Inverted Pyramid pattern
# *********
# ...
